# %%
import numpy as np
import scipy as sp
import networkx as nx

# %%
teams = [
    'FOX',
    'C9',
    '100',
    'TL',
    'CG',
    'FLY',
    'TSM',
    'CLG',
    'OPT',
    'GGS'
]

games = [
    # (winner, loser)
    # w1d1
    ('TL', 'TSM'),
    ('100', 'OPT'),
    ('CG', 'GGS'),
    ('FOX', 'FLY'),
    ('C9', 'CLG'),
    # w1d2
    ('TL', 'OPT'),
    ('FLY', 'TSM'),
    ('100', 'CLG'),
    ('C9', 'GGS'),
    ('FOX', 'CG'),
    # w2d1
    ('CG', 'CLG'),
    ('TSM', 'OPT'),
    ('FOX', 'C9'),
    ('100', 'TL'),
    ('FLY', 'GGS'),
    # w2d2
    ('FOX', 'TSM'),
    ('C9', '100'),
    ('OPT', 'FLY'),
    ('CLG', 'GGS'),
    ('TL', 'CG'),
]

wins = np.empty((len(teams),) * 2)
wins[teams.index('TL'), teams.index['TSM']]

print(wins)
# Out:
# [[8.30948601e-312 0.00000000e+000 8.48798316e-314 8.29700354e-312
#   8.30948624e-312 8.30948600e-312 8.30945952e-312 1.90979621e-313
#   8.29700354e-312 0.00000000e+000]
#  [8.30948633e-312 0.00000000e+000 8.48798317e-314 8.29700354e-312
#   8.30948623e-312 8.30948633e-312 8.30945952e-312 1.69759663e-313
#   8.29700354e-312 0.00000000e+000]
#  [8.30948374e-312 0.00000000e+000 8.48798317e-314 8.29700354e-312
#   8.30948624e-312 8.30874290e-312 8.30945952e-312 1.90979621e-313
#   8.29700354e-312 0.00000000e+000]
#  [8.30867232e-312 0.00000000e+000 8.48798317e-314 8.29700354e-312
#   8.30948624e-312 8.30948374e-312 8.30945952e-312 1.69759663e-313
#   8.29700354e-312 0.00000000e+000]
#  [1.50690022e-321 0.00000000e+000 8.48798317e-314 4.94065646e-324
#   8.30948624e-312 5.92878775e-323 8.30945952e-312 1.69759663e-313
#   0.00000000e+000 0.00000000e+000]
#  [7.90794572e-315 0.00000000e+000 8.48798317e-314 4.94065646e-324
# ...
